# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_excel('Downloads/Dataset_w6.xlsx')
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# # Find out how many countries are there in the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   country                                     196 non-null    object
#  1   Region                                      196 non-null    object
#  2   Surface area (km2)                          196 non-null    int64
#  3   Population in thousands (2017)              196 non-null    int64
#  4   GDP per capita (current US$)                196 non-null    float64
#  5   Agricultural production index               196 non-null    int64
#  6   International trade: Imports (million US$)  196 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 10.8+ KB

# %%
N=len(data['country'].value_counts())
print("Number_of_countries=", N)
# Out:
# Number_of_countries= 196

# %% [markdown]
# # Examine the data by using visualizations

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Region',y='GDP per capita (current US$)',data=data)
plt.title('Region VS GDP per capita (current US$)',fontsize=15)
plt.xticks(rotation = 45,fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Region',y='International trade: Imports (million US$)',data=data)
plt.title('Region VS International trade: Imports (million US$)', fontsize=15)
plt.xticks(rotation = 45,fontsize = 15)
plt.show()

# %% [markdown]
# # Find out how many countries with respect to the region are availablein the dataset

# %%
data['Region'].value_counts()
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# EasternAsia           7
# WesternEurope         7
# Polynesia             5
# CentralAsia           5
# NorthernAfrica        5
# SouthernAfrica        5
# Melanesia             5
# Micronesia            4
# NorthernAmerica       4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# # GDP per capita (current US$) average

# %%
data1=data.groupby("Region")['GDP per capita (current US$)'].mean().reset_index()
data1.sort_values('GDP per capita (current US$)',ascending=False)
# Out:
#                Region  GDP per capita (current US$)
# 10    NorthernAmerica                  57659.000000
# 21      WesternEurope                  55387.128571
# 12            Oceania                  44823.250000
# 11     NorthernEurope                  42098.220000
# 4         EasternAsia                  27967.614286
# 20        WesternAsia                  17013.938889
# 0           Caribbean                  15135.562500
# 18     SouthernEurope                  14462.741667
# 14  South-easternAsia                  10299.027273
# 5       EasternEurope                   9292.490000
# 6           Melanesia                   9261.960000
# 13          Polynesia                   8686.520000
# 15       SouthAmerica                   8499.775000
# 1      CentralAmerica                   6348.137500
# 7          Micronesia                   5008.300000
# 2         CentralAsia                   4329.880000
# 16     SouthernAfrica                   4191.900000
# ...

# %%
data1.nlargest(1,['GDP per capita (current US$)'])
# Out:
#              Region  GDP per capita (current US$)
# 10  NorthernAmerica                       57659.0

# %% [markdown]
# # International trade: Imports (million US$)

# %%
data2=data.groupby("Region")['International trade: Imports (million US$)'].mean().reset_index()
data2.sort_values('International trade: Imports (million US$)',ascending=False)
# Out:
#                Region  International trade: Imports (million US$)
# 10    NorthernAmerica                               663552.250000
# 4         EasternAsia                               451995.000000
# 21      WesternEurope                               407498.428571
# 11     NorthernEurope                               113407.200000
# 12            Oceania                               112914.500000
# 14  South-easternAsia                                98324.636364
# 5       EasternEurope                                85243.900000
# 18     SouthernEurope                                76666.666667
# 17       SouthernAsia                                58199.333333
# 1      CentralAmerica                                57031.500000
# 20        WesternAsia                                46025.555556
# 9      NorthernAfrica                                35034.400000
# 15       SouthAmerica                                32885.666667
# ...

# %%
data2.nlargest(1,['International trade: Imports (million US$)'])
# Out:
#              Region  International trade: Imports (million US$)
# 10  NorthernAmerica                                   663552.25

# %% [markdown]
# # Find out which region has more consistent with respect to GDP percapita (current US$)

# %%
data3=data.groupby("Region")['GDP per capita (current US$)'].std().reset_index()
data3.sort_values('GDP per capita (current US$)',ascending=False)
# Out:
#                Region  GDP per capita (current US$)
# 4         EasternAsia                  27485.120923
# 10    NorthernAmerica                  25749.619445
# 21      WesternEurope                  24770.467728
# 11     NorthernEurope                  20671.030185
# 20        WesternAsia                  18812.151459
# 14  South-easternAsia                  16311.810656
# 0           Caribbean                  14579.371326
# 6           Melanesia                  13855.842686
# 18     SouthernEurope                   9541.703216
# 12            Oceania                   9233.329638
# 13          Polynesia                   6956.250286
# 5       EasternEurope                   5415.488739
# 8        MiddleAfrica                   5274.846281
# 7          Micronesia                   4820.669694
# 15       SouthAmerica                   4273.707394
# 1      CentralAmerica                   4180.440883
# 2         CentralAsia                   4152.215490
# ...

# %%
data1.nsmallest(1,['GDP per capita (current US$)'])
# Out:
#            Region  GDP per capita (current US$)
# 19  WesternAfrica                       1013.14
